# %%
import requests
import json 
import pandas as pd


# 최대 200건
url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&count=200'
response = requests.get(url)
data_sample = pd.json_normalize(response.json())
data_sample
# Out:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-BTC  2024-03-06T07:50:00  2024-03-06T16:50:00     92782000.0
# 1    KRW-BTC  2024-03-06T07:49:00  2024-03-06T16:49:00     92796000.0
# 2    KRW-BTC  2024-03-06T07:48:00  2024-03-06T16:48:00     92829000.0
# 3    KRW-BTC  2024-03-06T07:47:00  2024-03-06T16:47:00     92950000.0
# 4    KRW-BTC  2024-03-06T07:46:00  2024-03-06T16:46:00     92949000.0
# ..       ...                  ...                  ...            ...
# 195  KRW-BTC  2024-03-06T04:35:00  2024-03-06T13:35:00     90000000.0
# 196  KRW-BTC  2024-03-06T04:34:00  2024-03-06T13:34:00     89900000.0
# 197  KRW-BTC  2024-03-06T04:33:00  2024-03-06T13:33:00     89776000.0
# 198  KRW-BTC  2024-03-06T04:32:00  2024-03-06T13:32:00     89837000.0
# 199  KRW-BTC  2024-03-06T04:31:00  2024-03-06T13:31:00     89857000.0
#
#      high_price   low_price  trade_price      timestamp  \
# 0    92850000.0  92780000.0   92847000.0  1709711459497
# ...

# %%
from datetime import datetime, timedelta
result_lst = []
exec_date = '2024-03-05'
start_time = '2024-03-06 00:00:00'

for i in range(60 * 24 // 200 + 1):
    url = 'https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTC&count=200&to=' + start_time
    response = requests.get(url).json()
    is_break = False
    if len(response) < 200:
        is_break = True
        print('shit1')
        
    for elem in response:
        if exec_date not in elem['candle_date_time_utc']:
            is_break = True
            print(exec_date, elem['candle_date_time_utc'])
            break
        result_lst.append(elem)
    start_time = response[-1]['candle_date_time_utc']
        
    if is_break:
        break
df = pd.json_normalize(result_lst)
df
# Out:
# 2024-03-05 2024-03-04T23:59:00
#        market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0     KRW-BTC  2024-03-05T23:59:00  2024-03-06T08:59:00     91125000.0
# 1     KRW-BTC  2024-03-05T23:58:00  2024-03-06T08:58:00     91353000.0
# 2     KRW-BTC  2024-03-05T23:57:00  2024-03-06T08:57:00     91400000.0
# 3     KRW-BTC  2024-03-05T23:56:00  2024-03-06T08:56:00     91256000.0
# 4     KRW-BTC  2024-03-05T23:55:00  2024-03-06T08:55:00     91522000.0
# ...       ...                  ...                  ...            ...
# 1435  KRW-BTC  2024-03-05T00:04:00  2024-03-05T09:04:00     95357000.0
# 1436  KRW-BTC  2024-03-05T00:03:00  2024-03-05T09:03:00     95355000.0
# 1437  KRW-BTC  2024-03-05T00:02:00  2024-03-05T09:02:00     95284000.0
# 1438  KRW-BTC  2024-03-05T00:01:00  2024-03-05T09:01:00     95292000.0
# 1439  KRW-BTC  2024-03-05T00:00:00  2024-03-05T09:00:00     95500000.0
#
#       high_price   low_price  trade_price      timestamp  \
# ...

# %%
datetime.strptime("2024-2-3", "%Y-%m-%d") + timedelta(days=1)
# Out:
# datetime.datetime(2024, 2, 4, 0, 0)
